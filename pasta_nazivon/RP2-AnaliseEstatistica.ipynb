# %%
import pandas as pd

# Carregar datasets
saneamento = pd.read_csv("Documents/dataset_saneamento_estado.csv")
dengue = pd.read_csv("Documents/dataset_dengue.csv")

# %%
populacao = pd.read_csv("Documents/SP_mun_população.csv")

# %%
# Conferir colunas disponíveis
print(saneamento.columns)
print(dengue.columns)
# Out:
# Index(['CD_MUN', 'NM_MUN_x', 'V00001', 'V00002', 'V00003', 'V00004', 'V00005',
#        'V00006', 'V00007', 'V00047',
#        ...
#        'V00612', 'V00613', 'V00614', 'V00615', 'V00616', 'V00617', 'V00636',
#        'V00637', 'V00638', 'V00639'],
#       dtype='object', length=101)
# Index(['CD_MUN', 'NM_MUN_x', 'DRS__0_level_1__0', 'DRS__1_level_1__1',
#        'GVE__2_level_1__2', 'GVE__3_level_1__3',
#        'Região_de_Saúde__4_level_1__4', 'Região_de_Saúde__5_level_1__5',
#        'Janeiro_notificados__7', 'Janeiro_confirmados_autóctones',
#        'Janeiro_confirmados_importados', 'Fevereiro_notificados__10',
#        'Fevereiro_confirmados_autóctones', 'Fevereiro_confirmados_importados',
#        'Março_notificados__13', 'Março_confirmados_autóctones',
#        'Março_confirmados_importados', 'Abril_notificados__16',
#        'Abril_confirmados_autóctones', 'Abril_confirmados_importados',
#        'Maio_notificados__19', 'Maio_confirmados_autóctones',
#        'Maio_confirmados_importados', 'Junho_notificados__22',
#        'Junho_confirmados_autóctones', 'Junho_confirmados_importados',
#        'Julho_notificados__25', 'Julho_confirmados_autóctones',
#        'Julho_confirmados_importados', 'Julho_notificados__28',
#        'Agosto_confirmados_autóctones', 'Agosto_confirmados_importados',
#        'Agosto_notificados__31', 'Setembro_confirmados_autóctones',
#        'Setembro_confirmados_importados', 'Setembro_notificados__34',
#        'Outubro_confirmados_autóctones', 'Outubro_confirmados_importados',
#        'Outubro_notificados__37', 'Novembro_confirmados_autóctones',
#        'Novembro_confirmados_importados', 'Novembro_notificados__40',
#        'Dezembro_confirmados_autóctones', 'Dezembro_confirmados_importados',
#        'Total_notificados__43', 'Total_confirmados_autóctones',
#        'Total_confirmados_importados', 'Janeiro_confirmados_total',
#        'Fevereiro_confirmados_total', 'Março_confirmados_total',
#        'Abril_confirmados_total', 'Maio_confirmados_total',
#        'Junho_confirmados_total', 'Julho_confirmados_total',
#        'Agosto_confirmados_total', 'Setembro_confirmados_total',
#        'Outubro_confirmados_total', 'Novembro_confirmados_total',
#        'Dezembro_confirmados_total', 'Total_confirmados_anual'],
#       dtype='object')

# %%
# Fazer o merge (união) dos dados
dados = pd.merge(dengue, saneamento, on="CD_MUN", how="inner")

dados.head()
# Out:
#     CD_MUN        NM_MUN_x_x  DRS__0_level_1__0      DRS__1_level_1__1  \
# 0  3500105        Adamantina                  9                Marília
# 1  3500204            Adolfo                 15  São José do Rio Preto
# 2  3500303             Aguaí                 14  São João da Boa Vista
# 3  3500402    Águas da Prata                 14  São João da Boa Vista
# 4  3500501  Águas de Lindóia                  7               Campinas
#
#   GVE__2_level_1__2      GVE__3_level_1__3  Região_de_Saúde__4_level_1__4  \
# 0               XIX                MARÍLIA                        35091.0
# 1              XXIX  SÃO JOSÉ DO RIO PRETO                        35156.0
# 2              XXVI  SÃO JOÃO DA BOA VISTA                        35142.0
# 3              XXVI  SÃO JOÃO DA BOA VISTA                        35142.0
# 4              XVII               CAMPINAS                        35074.0
#
#   Região_de_Saúde__5_level_1__5  Janeiro_notificados__7  \
# 0                    ADAMANTINA                      23
# 1                JOSÉ BONIFÁCIO                     102
# 2                   MANTIQUEIRA                       9
# 3                   MANTIQUEIRA                       0
# 4            CIRCUITO DAS AGUAS                       1
#
#    Janeiro_confirmados_autóctones  ...  V00612  V00613  V00614  V00615  \
# 0                               9  ...   33127     877     263      37
# 1                              49  ...    4186      83      78       4
# 2                               2  ...   29194    1081    1242      64
# 3                               0  ...    6866     283      96       0
# 4                               0  ...   16777     882      95       6
#
#    V00616  V00617  V00636  V00637  V00638  V00639
# 0       0     189      27    1047       0      75
# 1       0       0     186     324       9      36
# 2       4     413     232    2030      19     326
# 3       0      13      79     662      15      86
# 4       0      29     364     715      20      72
#
# [5 rows x 160 columns]

# %%
# Descrição do novo conjunto de dados
dados.describe()
# Out:
#              CD_MUN  DRS__0_level_1__0  Região_de_Saúde__4_level_1__4  \
# count  6.440000e+02         644.000000                     644.000000
# mean   3.528653e+06           9.709627                   35099.706522
# std    1.667514e+04           4.998087                      50.236262
# min    3.500105e+06           1.000000                   35011.000000
# 25%    3.514576e+06           6.000000                   35062.000000
# 50%    3.528650e+06           9.000000                   35095.000000
# 75%    3.543130e+06          15.000000                   35153.000000
# max    3.557204e+06          17.000000                   35174.000000
#
#        Janeiro_notificados__7  Janeiro_confirmados_autóctones  \
# count              644.000000                      644.000000
# mean                36.725155                       11.793478
# std                128.792915                       58.663412
# min                  0.000000                        0.000000
# 25%                  1.000000                        0.000000
# 50%                  5.000000                        0.500000
# 75%                 21.000000                        3.250000
# max               1861.000000                     1035.000000
#
#        Janeiro_confirmados_importados  Fevereiro_notificados__10  \
# count                      644.000000                 644.000000
# mean                         0.454969                  43.951863
# std                          2.441761                 144.961246
# min                          0.000000                   0.000000
# 25%                          0.000000                   1.000000
# 50%                          0.000000                   7.000000
# 75%                          0.000000                  26.500000
# max                         40.000000                2106.000000
#
#        Fevereiro_confirmados_autóctones  Fevereiro_confirmados_importados  \
# count                        644.000000                        644.000000
# mean                          23.833851                          0.543478
# std                           95.940780                          2.232860
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            1.000000                          0.000000
# 75%                           10.000000                          0.000000
# max                         1356.000000                         33.000000
#
#        Março_notificados__13  ...        V00612         V00613       V00614  \
# count             644.000000  ...  6.440000e+02     644.000000   644.000000
# mean              150.649068  ...  6.140737e+04    6365.012422   464.855590
# std               487.817762  ...  4.228468e+05   43660.917802   556.217686
# min                 0.000000  ...  5.340000e+02       0.000000     0.000000
# 25%                 4.000000  ...  4.687750e+03     133.000000   128.750000
# 50%                25.000000  ...  1.112850e+04     421.500000   264.500000
# 75%                96.750000  ...  3.576775e+04    1679.000000   604.750000
# max              6969.000000  ...  1.043332e+07  923195.000000  4992.000000
#
#            V00615        V00616       V00617        V00636       V00637  \
# count  644.000000    644.000000   644.000000    644.000000    644.00000
# mean    26.444099     81.251553   102.037267    606.215839   2382.77795
# std     42.625590    939.421608   382.244239   2106.284817   4632.98698
# min      0.000000      0.000000     0.000000      0.000000      0.00000
# 25%      4.000000      0.000000     7.000000     58.000000    466.00000
# 50%     14.000000      3.000000    33.000000    192.000000   1010.00000
# 75%     30.000000     12.250000    97.250000    523.500000   2563.00000
# max    513.000000  23226.000000  7757.000000  38436.000000  64836.00000
#
#             V00638        V00639
# count   644.000000    644.000000
# mean     66.723602    298.498447
# std     260.946002    678.658528
# min       0.000000      0.000000
# 25%       3.000000     49.000000
# 50%      17.000000    112.000000
# 75%      54.000000    305.000000
# max    5245.000000  11187.000000
#
# [8 rows x 154 columns]

# %%
# Merge (união) com o conjunto de dados que possui a população de cada município
dados_pop = pd.merge(dados, populacao, on="CD_MUN", how="inner")

dados_pop.head()
# Out:
#     CD_MUN        NM_MUN_x_x  DRS__0_level_1__0      DRS__1_level_1__1  \
# 0  3500105        Adamantina                  9                Marília
# 1  3500204            Adolfo                 15  São José do Rio Preto
# 2  3500303             Aguaí                 14  São João da Boa Vista
# 3  3500402    Águas da Prata                 14  São João da Boa Vista
# 4  3500501  Águas de Lindóia                  7               Campinas
#
#   GVE__2_level_1__2      GVE__3_level_1__3  Região_de_Saúde__4_level_1__4  \
# 0               XIX                MARÍLIA                        35091.0
# 1              XXIX  SÃO JOSÉ DO RIO PRETO                        35156.0
# 2              XXVI  SÃO JOÃO DA BOA VISTA                        35142.0
# 3              XXVI  SÃO JOÃO DA BOA VISTA                        35142.0
# 4              XVII               CAMPINAS                        35074.0
#
#   Região_de_Saúde__5_level_1__5  Janeiro_notificados__7  \
# 0                    ADAMANTINA                      23
# 1                JOSÉ BONIFÁCIO                     102
# 2                   MANTIQUEIRA                       9
# 3                   MANTIQUEIRA                       0
# 4            CIRCUITO DAS AGUAS                       1
#
#    Janeiro_confirmados_autóctones  ...  V00637  V00638  V00639  CD_REGIAO  \
# 0                               9  ...    1047       0      75          3
# 1                              49  ...     324       9      36          3
# 2                               2  ...    2030      19     326          3
# 3                               0  ...     662      15      86          3
# 4                               0  ...     715      20      72          3
#
#    NM_REGIAO  CD_UF      NM_UF            NM_MUN  Total_setores  População
# 0    Sudeste     35  São Paulo        Adamantina            107      34687
# 1    Sudeste     35  São Paulo            Adolfo             16       4351
# 2    Sudeste     35  São Paulo             Aguaí             63      32072
# 3    Sudeste     35  São Paulo    Águas da Prata             24       7369
# 4    Sudeste     35  São Paulo  Águas de Lindóia             49      17930
#
# [5 rows x 167 columns]

# %%
# Criação do coeficiente de incidência de dengue (dividindo o total de casos autóctones de dengue no município
# por sua população)
dados_pop['Total_autoctone_ponderado'] = dados_pop['Total_confirmados_autóctones'] / dados_pop['População']

# Conferir o resultado
dados_pop[['Total_confirmados_autóctones', 'População'] + ['Total_autoctone_ponderado']].head()
# Out:
#    Total_confirmados_autóctones  População  Total_autoctone_ponderado
# 0                          1357      34687                   0.039121
# 1                           176       4351                   0.040450
# 2                             5      32072                   0.000156
# 3                             0       7369                   0.000000
# 4                            11      17930                   0.000613

# %%
# Eliminação de algumas colunas redundantes ou não relevantes
dados_pop.drop(['CD_REGIAO','NM_REGIAO','CD_UF','NM_UF', 'NM_MUN', 'Total_setores'], axis=1)
# Out:
#       CD_MUN        NM_MUN_x_x  DRS__0_level_1__0      DRS__1_level_1__1  \
# 0    3500105        Adamantina                  9                Marília
# 1    3500204            Adolfo                 15  São José do Rio Preto
# 2    3500303             Aguaí                 14  São João da Boa Vista
# 3    3500402    Águas da Prata                 14  São João da Boa Vista
# 4    3500501  Águas de Lindóia                  7               Campinas
# ..       ...               ...                ...                    ...
# 639  3556958    Vitória Brasil                 15  São José do Rio Preto
# 640  3557006        Votorantim                 16               Sorocaba
# 641  3557105       Votuporanga                 15  São José do Rio Preto
# 642  3557154          Zacarias                 15  São José do Rio Preto
# 643  3557204         Chavantes                  9                Marília
#
#     GVE__2_level_1__2      GVE__3_level_1__3  Região_de_Saúde__4_level_1__4  \
# 0                 XIX                MARÍLIA                        35091.0
# 1                XXIX  SÃO JOSÉ DO RIO PRETO                        35156.0
# 2                XXVI  SÃO JOÃO DA BOA VISTA                        35142.0
# 3                XXVI  SÃO JOÃO DA BOA VISTA                        35142.0
# 4                XVII               CAMPINAS                        35074.0
# ..                ...                    ...                            ...
# 639               XXX                  JALES                        35153.0
# 640              XXXI               SOROCABA                        35163.0
# 641              XXIX  SÃO JOSÉ DO RIO PRETO                        35157.0
# 642              XXIX  SÃO JOSÉ DO RIO PRETO                        35156.0
# 643              XIII                  ASSIS                        35094.0
#
#     Região_de_Saúde__5_level_1__5  Janeiro_notificados__7  \
# 0                      ADAMANTINA                      23
# 1                  JOSÉ BONIFÁCIO                     102
# 2                     MANTIQUEIRA                       9
# 3                     MANTIQUEIRA                       0
# 4              CIRCUITO DAS AGUAS                       1
# ..                            ...                     ...
# 639                         JALES                      24
# 640                      SOROCABA                     132
# 641                   VOTUPORANGA                    1077
# 642                JOSÉ BONIFÁCIO                       5
# 643                      OURINHOS                       0
#
#      Janeiro_confirmados_autóctones  ...  V00614  V00615  V00616  V00617  \
# 0                                 9  ...     263      37       0     189
# 1                                49  ...      78       4       0       0
# 2                                 2  ...    1242      64       4     413
# 3                                 0  ...      96       0       0      13
# 4                                 0  ...      95       6       0      29
# ..                              ...  ...     ...     ...     ...     ...
# 639                              24  ...     114       0       0       0
# 640                               0  ...     207       4      10     134
# 641                             586  ...     974      61      17     174
# 642                               1  ...     216      26       0     176
# 643                               0  ...     109       0       0       6
#
#      V00636  V00637  V00638  V00639  População  Total_autoctone_ponderado
# 0        27    1047       0      75      34687                   0.039121
# 1       186     324       9      36       4351                   0.040450
# 2       232    2030      19     326      32072                   0.000156
# 3        79     662      15      86       7369                   0.000000
# 4       364     715      20      72      17930                   0.000613
# ..      ...     ...     ...     ...        ...                        ...
# 639      16     253       0      17       1794                   0.045708
# 640     231    3791      12     622     127923                   0.005128
# 641     322    2526      14     243      96634                   0.104021
# 642      53     510       0      59       2692                   0.044205
# 643      87     212      10      19      12211                   0.008107
#
# [644 rows x 162 columns]

# %%
# Variáveis de saneamento - Domicílios com determinadas características com relação a água, lixo e esgoto
cols_saneamento = ['V00111', 'V00112', 'V00113', 'V00114', 'V00115', 'V00116', 'V00117', 'V00118', 'V00199', 'V00200', 'V00201', 
             'V00309', 'V00310', 'V00311', 'V00312', 'V00313', 'V00314', 'V00315', 'V00316',
             'V00397', 'V00398', 'V00399', 'V00400', 'V00401', 'V00402', 'V00463', 'V00464']
# Criar novas colunas com os índices (divisão pelo total de domicílios)
for col in cols_saneamento:
    dados_pop[f'{col}_idx'] = dados_pop[col] / dados_pop['V00004']

# Conferir o resultado
dados_pop[['CD_MUN', 'V00004'] + [f'{c}_idx' for c in cols_saneamento]].head()
# Out:
#     CD_MUN  V00004  V00111_idx  V00112_idx  V00113_idx  V00114_idx  \
# 0  3500105   13567    0.970443    0.024913    0.003096    0.000000
# 1  3500204    1650    0.881818    0.103030    0.007879    0.000000
# 2  3500303   11480    0.933537    0.038240    0.019164    0.006707
# 3  3500402    2830    0.897527    0.016608    0.004240    0.075265
# 4  3500501    6799    0.941021    0.015002    0.003530    0.034270
#
#    V00115_idx  V00116_idx  V00117_idx  V00118_idx  ...  V00315_idx  \
# 0    0.000000         0.0         0.0         0.0  ...    0.000000
# 1    0.000000         0.0         0.0         0.0  ...    0.000000
# 2    0.000436         0.0         0.0         0.0  ...    0.000958
# 3    0.000000         0.0         0.0         0.0  ...    0.002473
# 4    0.000000         0.0         0.0         0.0  ...    0.000441
#
#    V00316_idx  V00397_idx  V00398_idx  V00399_idx  V00400_idx  V00401_idx  \
# 0         0.0    0.958944    0.026461    0.006929    0.000884         0.0
# 1         0.0    0.961818    0.017576    0.018182    0.000000         0.0
# 2         0.0    0.918990    0.029268    0.035192    0.001307         0.0
# 3         0.0    0.945230    0.038163    0.011661    0.000000         0.0
# 4         0.0    0.941756    0.048831    0.003971    0.000000         0.0
#
#    V00402_idx  V00463_idx  V00464_idx
# 0    0.005012    0.000295    0.027935
# 1    0.000000    0.042424    0.069091
# 2    0.011672    0.006707    0.058449
# 3    0.001413    0.008127    0.089753
# 4    0.000441    0.018679    0.037064
#
# [5 rows x 29 columns]

# %%
# Baixar o conjunto de dados como CSV
dados_pop.to_csv('RP2dados_unidos.csv', index=False)

# %%
# PRIMEIRA ANÁLISE: Selecionar colunas relevantes para análise - Índices e a variável alvo
variaveis = ['Total_autoctone_ponderado', 
             'V00111_idx', 'V00112_idx', 'V00113_idx', 'V00114_idx', 'V00115_idx', 'V00116_idx', 'V00117_idx',
             'V00118_idx', 'V00199_idx', 'V00200_idx', 'V00201_idx', 'V00309_idx', 'V00310_idx', 'V00311_idx', 
             'V00312_idx', 'V00313_idx', 'V00314_idx', 'V00315_idx', 'V00316_idx', 'V00397_idx', 'V00398_idx',
             'V00399_idx', 'V00400_idx', 'V00401_idx', 'V00402_idx', 'V00463_idx', 'V00464_idx']

# Correlação das variáveis
corr = dados_pop[variaveis].corr(method='pearson')

# Ordenar as correlações em ordem decrescente
corr_ordenado = corr['Total_autoctone_ponderado'].sort_values(ascending=False)

print(corr_ordenado)
# Out:
# Total_autoctone_ponderado    1.000000
# V00112_idx                   0.249106
# V00400_idx                   0.216554
# V00399_idx                   0.190239
# V00309_idx                   0.184772
# V00401_idx                   0.167820
# V00199_idx                   0.110704
# V00397_idx                   0.104629
# V00402_idx                   0.095514
# V00111_idx                   0.070873
# V00463_idx                  -0.011200
# V00310_idx                  -0.040684
# V00200_idx                  -0.043127
# V00316_idx                  -0.063338
# V00464_idx                  -0.073737
# V00312_idx                  -0.078512
# V00116_idx                  -0.084663
# V00117_idx                  -0.094189
# V00115_idx                  -0.116568
# V00118_idx                  -0.129704
# V00201_idx                  -0.136351
# V00315_idx                  -0.154120
# V00313_idx                  -0.176149
# V00311_idx                  -0.177487
# V00113_idx                  -0.179108
# V00398_idx                  -0.189694
# V00314_idx                  -0.225478
# V00114_idx                  -0.237738
# Name: Total_autoctone_ponderado, dtype: float64

# %%
# Selecionar apenas as colunas numéricas do conjunto de dados
dados_numericos = dados_pop.select_dtypes(include=['number'])

# %%
# Eliminação de algumas colunas não relevantes
dados_numericos.drop(['DRS__0_level_1__0', 'Região_de_Saúde__4_level_1__4'], axis=1)
# Out:
#       CD_MUN  Janeiro_notificados__7  Janeiro_confirmados_autóctones  \
# 0    3500105                      23                               9
# 1    3500204                     102                              49
# 2    3500303                       9                               2
# 3    3500402                       0                               0
# 4    3500501                       1                               0
# ..       ...                     ...                             ...
# 639  3556958                      24                              24
# 640  3557006                     132                               0
# 641  3557105                    1077                             586
# 642  3557154                       5                               1
# 643  3557204                       0                               0
#
#      Janeiro_confirmados_importados  Fevereiro_notificados__10  \
# 0                                 0                         21
# 1                                 0                         37
# 2                                 0                          3
# 3                                 0                          0
# 4                                 0                          0
# ..                              ...                        ...
# 639                               0                         11
# 640                               0                         75
# 641                               0                       1620
# 642                               1                         18
# 643                               0                          1
#
#      Fevereiro_confirmados_autóctones  Fevereiro_confirmados_importados  \
# 0                                   7                                 0
# 1                                  28                                 0
# 2                                   1                                 0
# 3                                   0                                 0
# 4                                   0                                 0
# ..                                ...                               ...
# 639                                11                                 0
# 640                                 6                                 1
# 641                              1292                                 0
# 642                                15                                 0
# 643                                 0                                 0
#
#      Março_notificados__13  Março_confirmados_autóctones  \
# 0                      166                           128
# 1                       68                            48
# 2                        5                             1
# 3                        3                             0
# 4                        1                             0
# ..                     ...                           ...
# 639                     15                            14
# 640                    159                            65
# 641                   3292                          2830
# 642                    125                            98
# 643                     19                            11
#
#      Março_confirmados_importados  ...  V00315_idx  V00316_idx  V00397_idx  \
# 0                               0  ...    0.000000    0.000000    0.958944
# 1                               0  ...    0.000000    0.000000    0.961818
# 2                               0  ...    0.000958    0.000000    0.918990
# 3                               0  ...    0.002473    0.000000    0.945230
# 4                               1  ...    0.000441    0.000000    0.941756
# ..                            ...  ...         ...         ...         ...
# 639                             0  ...    0.000000    0.000000    0.900433
# 640                             1  ...    0.000654    0.000068    0.834006
# 641                             1  ...    0.000000    0.000000    0.980824
# 642                             0  ...    0.000000    0.000000    0.836019
# 643                             3  ...    0.023256    0.000000    0.981580
#
#      V00398_idx  V00399_idx  V00400_idx  V00401_idx  V00402_idx  V00463_idx  \
# 0      0.026461    0.006929    0.000884    0.000000    0.005012    0.000295
# 1      0.017576    0.018182    0.000000    0.000000    0.000000    0.042424
# 2      0.029268    0.035192    0.001307    0.000000    0.011672    0.006707
# 3      0.038163    0.011661    0.000000    0.000000    0.001413    0.008127
# 4      0.048831    0.003971    0.000000    0.000000    0.000441    0.018679
# ..          ...         ...         ...         ...         ...         ...
# 639    0.034632    0.060606    0.000000    0.000000    0.000000    0.004329
# 640    0.162114    0.000992    0.000000    0.000000    0.000880    0.001105
# 641    0.006937    0.009026    0.000509    0.000161    0.001687    0.003294
# 642    0.020853    0.078673    0.008531    0.000000    0.053081    0.017062
# 643    0.007829    0.008980    0.000000    0.000000    0.000000    0.006677
#
#      V00464_idx
# 0      0.027935
# 1      0.069091
# 2      0.058449
# 3      0.089753
# 4      0.037064
# ..          ...
# 639    0.139971
# 640    0.029436
# 641    0.024908
# 642    0.170616
# 643    0.016578
#
# [644 rows x 184 columns]

# %%
# Correlações entre as variáveis numéricas e a variável alvo
correlacoes = dados_numericos.corr(method='pearson')['Total_autoctone_ponderado']

correlacoes = correlacoes.sort_values(ascending=False)

print(correlacoes)
# Out:
# Total_autoctone_ponderado           1.000000
# Março_confirmados_total             0.311297
# Março_confirmados_autóctones        0.311198
# Fevereiro_confirmados_total         0.295147
# Fevereiro_confirmados_autóctones    0.293674
#                                       ...
# V00314_idx                         -0.225478
# V00114_idx                         -0.237738
# V00051                                   NaN
# CD_REGIAO                                NaN
# CD_UF                                    NaN
# Name: Total_autoctone_ponderado, Length: 186, dtype: float64

# %%
# Criação de um gráfico mostrando o Coeficiente de Correlação de Pearson 
# de cada uma das variáveis analisadas com relação à variável alvo
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
corr_ordenado.drop('Total_autoctone_ponderado').plot(kind='bar')
plt.title('Correlação das variáveis com Total_confirmados_autóctones')
plt.ylabel('Coeficiente de correlação de Pearson')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
# Importação de ferramentas para normalização, regressão linear e múltipla
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

# %%
# Nova declaração dos dados puramente numéricos
dados_numericos = dados_pop.select_dtypes(include=['int64', 'float64']).copy()

# %%
# Verificar se a coluna-alvo está presente
alvo = "Total_autoctone_ponderado"
if alvo not in dados_numericos.columns:
    raise ValueError(f"A coluna alvo '{alvo}' não foi encontrada nas colunas numéricas.")

# %%
# === Normalização (Min-Max) ===
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dados_norm = pd.DataFrame(scaler.fit_transform(dados_numericos),
                          columns=dados_numericos.columns)

# %%
print(dados_norm)
# Out:
#        CD_MUN  DRS__0_level_1__0  Região_de_Saúde__4_level_1__4  \
# 0   -1.713368          -0.142090                      -0.173446
# 1   -1.707427           1.059302                       1.121446
# 2   -1.701485           0.859070                       0.842546
# 3   -1.695544           0.859070                       0.842546
# 4   -1.689602          -0.542554                      -0.512110
# ..        ...                ...                            ...
# 639  1.698729           1.059302                       1.061681
# 640  1.701610           1.259534                       1.260895
# 641  1.707551           1.059302                       1.141367
# 642  1.710492           1.059302                       1.121446
# 643  1.713493          -0.142090                      -0.113682
#
#      Janeiro_notificados__7  Janeiro_confirmados_autóctones  \
# 0                 -0.106650                       -0.047656
# 1                  0.507214                        0.634730
# 2                 -0.215437                       -0.167073
# 3                 -0.285371                       -0.201193
# 4                 -0.277600                       -0.201193
# ..                      ...                             ...
# 639               -0.098880                        0.208239
# 640                0.740327                       -0.201193
# 641                8.083391                        9.795763
# 642               -0.246518                       -0.184133
# 643               -0.285371                       -0.201193
#
#      Janeiro_confirmados_importados  Fevereiro_notificados__10  \
# 0                         -0.186473                  -0.158454
# 1                         -0.186473                  -0.047994
# 2                         -0.186473                  -0.282722
# 3                         -0.186473                  -0.303433
# 4                         -0.186473                  -0.303433
# ..                              ...                        ...
# 639                       -0.186473                  -0.227492
# 640                       -0.186473                   0.214349
# 641                       -0.186473                  10.880654
# 642                        0.223386                  -0.179165
# 643                       -0.186473                  -0.296529
#
#      Fevereiro_confirmados_autóctones  Fevereiro_confirmados_importados  \
# 0                           -0.175597                         -0.243589
# 1                            0.043458                         -0.243589
# 2                           -0.238184                         -0.243589
# 3                           -0.248616                         -0.243589
# 4                           -0.248616                         -0.243589
# ..                                ...                               ...
# 639                         -0.133872                         -0.243589
# 640                         -0.186028                          0.204615
# 641                         13.228493                         -0.243589
# 642                         -0.092148                         -0.243589
# 643                         -0.248616                         -0.243589
#
#      Março_notificados__13  ...  V00315_idx  V00316_idx  V00397_idx  \
# 0                 0.031493  ...   -0.311080   -0.101939    0.567371
# 1                -0.169558  ...   -0.311080   -0.101939    0.591274
# 2                -0.298805  ...    0.188509   -0.101939    0.235028
# 3                -0.302908  ...    0.978576   -0.101939    0.453292
# 4                -0.307011  ...   -0.081022   -0.101939    0.424399
# ..                     ...  ...         ...         ...         ...
# 639              -0.278289  ...   -0.311080   -0.101939    0.080674
# 640               0.017132  ...    0.029982    0.069007   -0.471859
# 641               6.444605  ...   -0.311080   -0.101939    0.749362
# 642              -0.052620  ...   -0.311080   -0.101939   -0.455118
# 643              -0.270083  ...   11.814265   -0.101939    0.755648
#
#      V00398_idx  V00399_idx  V00400_idx  V00401_idx  V00402_idx  V00463_idx  \
# 0     -0.349950   -0.669974   -0.170160   -0.265228    0.282812   -0.599775
# 1     -0.427126   -0.383100   -0.408567   -0.265228   -0.570640    0.773090
# 2     -0.325569    0.050525   -0.056382   -0.265228    1.416906   -0.390812
# 3     -0.248316   -0.549338   -0.408567   -0.265228   -0.329967   -0.344542
# 4     -0.155657   -0.745366   -0.408567   -0.265228   -0.495507   -0.000685
# ..          ...         ...         ...         ...         ...         ...
# 639   -0.278981    0.698404   -0.408567   -0.265228   -0.570640   -0.468314
# 640    0.828281   -0.821301   -0.408567   -0.265228   -0.420847   -0.573365
# 641   -0.519533   -0.616514   -0.271408   -0.192518   -0.283335   -0.502034
# 642   -0.398660    1.158977    1.890820   -0.265228    8.467725   -0.053398
# 643   -0.511785   -0.617679   -0.408567   -0.265228   -0.570640   -0.391787
#
#      V00464_idx
# 0     -0.764206
# 1     -0.358893
# 2     -0.463694
# 3     -0.155410
# 4     -0.674302
# ..          ...
# 639    0.339158
# 640   -0.749425
# 641   -0.794025
# 642    0.640960
# 643   -0.876053
#
# [644 rows x 186 columns]

# %%
# Obter os dados normalizados em CSV, para disponibilização
dados_norm.to_csv('dados_normalizados.csv', index=False)

# %%
# === Correlação de Pearson (todas contra todas) ===
corr = dados_norm.corr(method='pearson')

# %%
# Ordenar correlações da variável alvo (do maior ao menor)
corr_alvo = corr[alvo].sort_values(ascending=False)
print("\nCorrelação de Pearson com a variável alvo:")
print(corr_alvo)
# Out:
# Correlação de Pearson com a variável alvo:
# Total_autoctone_ponderado           1.000000
# Março_confirmados_total             0.311297
# Março_confirmados_autóctones        0.311198
# Fevereiro_confirmados_total         0.295147
# Fevereiro_confirmados_autóctones    0.293674
#                                       ...
# V00314_idx                         -0.225478
# V00114_idx                         -0.237738
# V00051                                   NaN
# CD_REGIAO                                NaN
# CD_UF                                    NaN
# Name: Total_autoctone_ponderado, Length: 186, dtype: float64

# %%
# === Regressão Linear Simples (cada variável vs. alvo) ===
print("\n=== Regressão Linear Simples ===")
for var in dados_norm.columns:
    if var == alvo:
        continue
    X = dados_norm[[var]]
    y = dados_norm[alvo]
    model = LinearRegression().fit(X, y)
    y_pred = model.predict(X)
    r2 = r2_score(y, y_pred)
    print(f"{var}: R² = {r2:.4f}")
# Out:
# === Regressão Linear Simples ===
# CD_MUN: R² = 0.0013
# DRS__0_level_1__0: R² = 0.0012
# Região_de_Saúde__4_level_1__4: R² = 0.0017
# Janeiro_notificados__7: R² = 0.0113
# Janeiro_confirmados_autóctones: R² = 0.0448
# Janeiro_confirmados_importados: R² = 0.0008
# Fevereiro_notificados__10: R² = 0.0526
# Fevereiro_confirmados_autóctones: R² = 0.0862
# Fevereiro_confirmados_importados: R² = 0.0158
# Março_notificados__13: R² = 0.0718
# Março_confirmados_autóctones: R² = 0.0968
# Março_confirmados_importados: R² = 0.0212
# Abril_notificados__16: R² = 0.0345
# Abril_confirmados_autóctones: R² = 0.0626
# Abril_confirmados_importados: R² = 0.0025
# Maio_notificados__19: R² = 0.0065
# Maio_confirmados_autóctones: R² = 0.0292
# Maio_confirmados_importados: R² = 0.0004
# Junho_notificados__22: R² = 0.0004
# Junho_confirmados_autóctones: R² = 0.0160
# Junho_confirmados_importados: R² = 0.0005
# Julho_notificados__25: R² = 0.0000
# Julho_confirmados_autóctones: R² = 0.0107
# Julho_confirmados_importados: R² = 0.0033
# Julho_notificados__28: R² = 0.0004
# Agosto_confirmados_autóctones: R² = 0.0052
# Agosto_confirmados_importados: R² = 0.0004
# Agosto_notificados__31: R² = 0.0014
# Setembro_confirmados_autóctones: R² = 0.0022
# Setembro_confirmados_importados: R² = 0.0010
# Setembro_notificados__34: R² = 0.0007
# Outubro_confirmados_autóctones: R² = 0.0023
# Outubro_confirmados_importados: R² = 0.0004
# Outubro_notificados__37: R² = 0.0002
# Novembro_confirmados_autóctones: R² = 0.0030
# Novembro_confirmados_importados: R² = 0.0002
# Novembro_notificados__40: R² = 0.0000
# Dezembro_confirmados_autóctones: R² = 0.0034
# Dezembro_confirmados_importados: R² = 0.0007
# Total_notificados__43: R² = 0.0156
# Total_confirmados_autóctones: R² = 0.0578
# Total_confirmados_importados: R² = 0.0042
# Janeiro_confirmados_total: R² = 0.0447
# Fevereiro_confirmados_total: R² = 0.0871
# Março_confirmados_total: R² = 0.0969
# Abril_confirmados_total: R² = 0.0621
# Maio_confirmados_total: R² = 0.0290
# Junho_confirmados_total: R² = 0.0158
# Julho_confirmados_total: R² = 0.0102
# Agosto_confirmados_total: R² = 0.0051
# Setembro_confirmados_total: R² = 0.0021
# Outubro_confirmados_total: R² = 0.0023
# Novembro_confirmados_total: R² = 0.0031
# Dezembro_confirmados_total: R² = 0.0035
# Total_confirmados_anual: R² = 0.0575
# V00001: R² = 0.0040
# V00002: R² = 0.0014
# V00003: R² = 0.0036
# V00004: R² = 0.0040
# V00005: R² = 0.0042
# V00006: R² = 0.0016
# V00007: R² = 0.0034
# V00047: R² = 0.0049
# V00048: R² = 0.0066
# V00049: R² = 0.0022
# V00050: R² = 0.0020
# V00051: R² = 0.0000
# V00052: R² = 0.0056
# V00111: R² = 0.0038
# V00112: R² = 0.0080
# V00113: R² = 0.0263
# V00114: R² = 0.0405
# V00115: R² = 0.0152
# V00116: R² = 0.0091
# V00117: R² = 0.0042
# V00118: R² = 0.0031
# V00119: R² = 0.0046
# V00120: R² = 0.0145
# V00121: R² = 0.0266
# V00122: R² = 0.0411
# V00123: R² = 0.0147
# V00124: R² = 0.0087
# V00125: R² = 0.0039
# V00126: R² = 0.0030
# V00127: R² = 0.0062
# V00128: R² = 0.0017
# V00129: R² = 0.0044
# V00130: R² = 0.0069
# V00131: R² = 0.0030
# V00132: R² = 0.0007
# V00133: R² = 0.0027
# V00134: R² = 0.0036
# V00135: R² = 0.0023
# V00136: R² = 0.0002
# V00137: R² = 0.0001
# V00138: R² = 0.0034
# V00139: R² = 0.0035
# V00140: R² = 0.0013
# V00141: R² = 0.0010
# V00142: R² = 0.0039
# V00199: R² = 0.0039
# V00200: R² = 0.0143
# V00201: R² = 0.0160
# V00309: R² = 0.0035
# V00310: R² = 0.0095
# V00311: R² = 0.0329
# V00312: R² = 0.0368
# V00313: R² = 0.0112
# V00314: R² = 0.0033
# V00315: R² = 0.0032
# V00316: R² = 0.0061
# V00397: R² = 0.0037
# V00398: R² = 0.0062
# V00399: R² = 0.0023
# V00400: R² = 0.0089
# V00401: R² = 0.0019
# V00402: R² = 0.0069
# V00463: R² = 0.0056
# V00464: R² = 0.0384
# V00465: R² = 0.0170
# V00466: R² = 0.0387
# V00467: R² = 0.0000
# V00468: R² = 0.0124
# V00469: R² = 0.0002
# V00470: R² = 0.0017
# V00508: R² = 0.0040
# V00509: R² = 0.0105
# V00510: R² = 0.0265
# V00511: R² = 0.0395
# V00512: R² = 0.0168
# V00513: R² = 0.0106
# V00514: R² = 0.0055
# V00515: R² = 0.0033
# V00540: R² = 0.0042
# V00541: R² = 0.0135
# V00542: R² = 0.0163
# V00580: R² = 0.0038
# V00581: R² = 0.0092
# V00582: R² = 0.0319
# V00583: R² = 0.0353
# V00584: R² = 0.0115
# V00585: R² = 0.0034
# V00586: R² = 0.0035
# V00587: R² = 0.0055
# V00612: R² = 0.0039
# V00613: R² = 0.0065
# V00614: R² = 0.0037
# V00615: R² = 0.0033
# V00616: R² = 0.0020
# V00617: R² = 0.0074
# V00636: R² = 0.0074
# V00637: R² = 0.0379
# V00638: R² = 0.0076
# V00639: R² = 0.0341
# CD_REGIAO: R² = 0.0000
# CD_UF: R² = 0.0000
# Total_setores: R² = 0.0037
# População: R² = 0.0042
# V00111_idx: R² = 0.0050
# V00112_idx: R² = 0.0621
# V00113_idx: R² = 0.0321
# V00114_idx: R² = 0.0565
# V00115_idx: R² = 0.0136
# V00116_idx: R² = 0.0072
# V00117_idx: R² = 0.0089
# V00118_idx: R² = 0.0168
# V00199_idx: R² = 0.0123
# V00200_idx: R² = 0.0019
# V00201_idx: R² = 0.0186
# V00309_idx: R² = 0.0341
# V00310_idx: R² = 0.0017
# V00311_idx: R² = 0.0315
# V00312_idx: R² = 0.0062
# V00313_idx: R² = 0.0310
# V00314_idx: R² = 0.0508
# V00315_idx: R² = 0.0238
# V00316_idx: R² = 0.0040
# V00397_idx: R² = 0.0109
# V00398_idx: R² = 0.0360
# V00399_idx: R² = 0.0362
# V00400_idx: R² = 0.0469
# V00401_idx: R² = 0.0282
# V00402_idx: R² = 0.0091
# V00463_idx: R² = 0.0001
# V00464_idx: R² = 0.0054

# %%
# === Regressão Linear Múltipla (todas variáveis vs. alvo) ===
X = dados_norm.drop(columns=[alvo])
y = dados_norm[alvo]

modelo_multi = LinearRegression().fit(X, y)
y_pred_multi = modelo_multi.predict(X)

r2_multi = r2_score(y, y_pred_multi)
mae = mean_absolute_error(y, y_pred_multi)
rmse = np.sqrt(mean_squared_error(y, y_pred_multi))

print("\n=== Regressão Linear Múltipla ===")
print(f"R²: {r2_multi:.4f}")
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
# Out:
# === Regressão Linear Múltipla ===
# R²: 0.5628
# MAE: 0.4534
# RMSE: 0.6612

# %%
# === Selecionar variáveis independentes que começam com "V00", que são as do saneamento ===
variaveis_v00 = [col for col in dados_numericos.columns if col.startswith("V00")]

# %%
# === Criar novo DataFrame apenas com as variáveis relevantes ===
dados_filtrados = dados_numericos[variaveis_v00 + [alvo]]

# %%
# === Normalização (Min-Max) ===
scaler = StandardScaler()
dados_norm = pd.DataFrame(scaler.fit_transform(dados_filtrados),
                          columns=dados_filtrados.columns)

# %%
# === Correlação de Pearson ===
corr = dados_norm.corr(method='pearson')
corr_alvo = corr[alvo].sort_values(ascending=False)

print("\nCorrelação de Pearson (variáveis V00... vs Total_autoctone_ponderado):")
print(corr_alvo)
# Out:
# Correlação de Pearson (variáveis V00... vs Total_autoctone_ponderado):
# Total_autoctone_ponderado    1.000000
# V00112_idx                   0.249106
# V00400_idx                   0.216554
# V00399_idx                   0.190239
# V00309_idx                   0.184772
#                                ...
# V00114                      -0.201329
# V00122                      -0.202754
# V00314_idx                  -0.225478
# V00114_idx                  -0.237738
# V00051                            NaN
# Name: Total_autoctone_ponderado, Length: 127, dtype: float64

# %%
# === Regressão Linear Múltipla (todas as V00... como independentes) ===
X = dados_norm[variaveis_v00]
y = dados_norm[alvo]

modelo = LinearRegression().fit(X, y)
y_pred = modelo.predict(X)

r2 = r2_score(y, y_pred)
mae = mean_absolute_error(y, y_pred)
rmse = np.sqrt(mean_squared_error(y, y_pred))

print("\n=== Regressão Linear Múltipla (variáveis V00...) ===")
print(f"R²: {r2:.4f}")
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
# Out:
# === Regressão Linear Múltipla (variáveis V00...) ===
# R²: 0.3100
# MAE: 0.5641
# RMSE: 0.8307

# %%
# === (Opcional) Mostrar os coeficientes ordenados ===
coeficientes = pd.Series(modelo.coef_, index=variaveis_v00).sort_values(ascending=False)
print("\nCoeficientes (influência de cada variável):")
print(coeficientes)
# Out:
# Coeficientes (influência de cada variável):
# V00004    2.397352e+10
# V00005    5.469684e+03
# V00111    3.130931e+03
# V00199    1.221143e+03
# V00397    8.565199e+02
#               ...
# V00612   -7.574208e+02
# V00049   -8.751302e+02
# V00119   -9.610293e+02
# V00508   -3.346897e+03
# V00001   -2.397353e+10
# Length: 126, dtype: float64

# %%
import seaborn as sns
import statsmodels.api as sm

# %%
# Mostrar apenas as 15 variáveis mais correlacionadas com o alvo
top_n = 15
top_corr = corr_alvo.drop(alvo).head(top_n)

plt.figure(figsize=(8, 6))
sns.barplot(x=top_corr.values, y=top_corr.index, palette="coolwarm")
plt.title(f"Top {top_n} variáveis mais correlacionadas com a incidência de dengue")
plt.xlabel("Correlação de Pearson")
plt.ylabel("Variável")
plt.tight_layout()
plt.show()

# %%
top_vars = corr_alvo.drop(alvo).head(4).index  # 4 variáveis mais correlacionadas
for var in top_vars:
    plt.figure(figsize=(5, 4))
    sns.scatterplot(x=dados_norm[var], y=dados_norm[alvo], alpha=0.6)
    plt.title(f"{var} vs Total_autoctone_ponderado")
    plt.xlabel(f"{var}")
    plt.ylabel("Incidência de dengue")
    plt.tight_layout()
    plt.show()

# %%
# === Regressão Linear Múltipla (novamente) ===
X = dados_norm[variaveis_v00]
y = dados_norm[alvo]

modelo = LinearRegression().fit(X, y)
y_pred = modelo.predict(X)

r2 = r2_score(y, y_pred)
mae = mean_absolute_error(y, y_pred)
rmse = np.sqrt(mean_squared_error(y, y_pred))

print("\n=== Regressão Linear Múltipla ===")
print(f"R²: {r2:.4f}")
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
# Out:
# === Regressão Linear Múltipla ===
# R²: 0.3100
# MAE: 0.5641
# RMSE: 0.8307

# %%
# === Gráfico Fits Plot (observado vs predito) ===
plt.figure(figsize=(6, 6))
sns.scatterplot(x=y, y=y_pred, alpha=0.7)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  # linha 45°
plt.xlabel("Valor Real (normalizado)")
plt.ylabel("Valor Predito (normalizado)")
plt.title("Fits Plot - Observado vs Predito")
plt.tight_layout()
plt.show()

# %%
# === Q-Q Plot dos resíduos ===
residuos = y - y_pred

sm.qqplot(residuos, line='45', fit=True)
plt.title("Q-Q Plot dos Resíduos")
plt.tight_layout()
plt.show()

# %%
# === Histograma dos resíduos ===
plt.figure(figsize=(6, 4))
sns.histplot(residuos, kde=True)
plt.title("Distribuição dos Resíduos")
plt.xlabel("Resíduo (erro)")
plt.ylabel("Frequência")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Nazivon Santos\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
